# %% [markdown]
# # For lab3 solutions please scroll down.
#
# **The first part of this jupyter notebook is for lab2**
#
# ## Important: I used the cleaned dataset from Lab2 for this, not the new one given in lab3 repo

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv("marketing_customer_analysis.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %%
#Show the dataframe shape.
data.shape
# Out:
# (10910, 26)

# %%
data.info()
display(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
#  12  Marital Status                 10910 non-null  object
#  13  Monthly Premium Auto           10910 non-null  int64
#  14  Months Since Last Claim        10277 non-null  float64
#  15  Months Since Policy Inception  10910 non-null  int64
#  16  Number of Open Complaints      10277 non-null  float64
#  17  Number of Policies             10910 non-null  int64
#  18  Policy Type                    10910 non-null  object
#  19  Policy                         10910 non-null  object
#  20  Renew Offer Type               10910 non-null  object
#  21  Sales Channel                  10910 non-null  object
#  22  Total Claim Amount             10910 non-null  float64
#  23  Vehicle Class                  10288 non-null  object
#  24  Vehicle Size                   10288 non-null  object
#  25  Vehicle Type                   5428 non-null   object
# dtypes: float64(4), int64(5), object(17)
# memory usage: 2.2+ MB
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
#Standardize header names.
cols = []
for column in data.columns:
    cols.append(column.lower())
data.columns = cols

# %%
data = data.rename(columns={'unnamed: 0':'index'})

# %%
#dropping this as we already have an index
data = data.drop(['index'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10279 non-null  object
#  2   customer lifetime value        10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective to date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location code                  10910 non-null  object
#  11  marital status                 10910 non-null  object
#  12  monthly premium auto           10910 non-null  int64
#  13  months since last claim        10277 non-null  float64
#  14  months since policy inception  10910 non-null  int64
#  15  number of open complaints      10277 non-null  float64
#  16  number of policies             10910 non-null  int64
#  17  policy type                    10910 non-null  object
#  18  policy                         10910 non-null  object
#  19  renew offer type               10910 non-null  object
#  20  sales channel                  10910 non-null  object
#  21  total claim amount             10910 non-null  float64
#  22  vehicle class                  10288 non-null  object
#  23  vehicle size                   10288 non-null  object
#  24  vehicle type                   5428 non-null   object
# dtypes: float64(4), int64(4), object(17)
# memory usage: 2.1+ MB

# %%
#Which columns are numerical?

list(data.select_dtypes(['number']))
# Out:
# ['customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'months since last claim',
#  'months since policy inception',
#  'number of open complaints',
#  'number of policies',
#  'total claim amount']

# %%
#Which columns are categorical?
#Answer: state','response','coverage','education',employment status, gender, marital status,
#policy type, renew offer type, sales channel, vehicle class, vehicle size, vehicle type
list(data.select_dtypes(['object']))
# Out:
# ['customer',
#  'state',
#  'response',
#  'coverage',
#  'education',
#  'effective to date',
#  'employmentstatus',
#  'gender',
#  'location code',
#  'marital status',
#  'policy type',
#  'policy',
#  'renew offer type',
#  'sales channel',
#  'vehicle class',
#  'vehicle size',
#  'vehicle type']

# %%
#Check and deal with NaN values.
data.isna().sum()
# Out:
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# vehicle type                     5482
# dtype: int64

# %%
round(data.isna().sum()/data.shape[0],4)*100
# Out:
# customer                          0.00
# state                             5.78
# customer lifetime value           0.00
# response                          5.78
# coverage                          0.00
# education                         0.00
# effective to date                 0.00
# employmentstatus                  0.00
# gender                            0.00
# income                            0.00
# location code                     0.00
# marital status                    0.00
# monthly premium auto              0.00
# months since last claim           5.80
# months since policy inception     0.00
# number of open complaints         5.80
# number of policies                0.00
# policy type                       0.00
# policy                            0.00
# renew offer type                  0.00
# sales channel                     0.00
# total claim amount                0.00
# vehicle class                     5.70
# vehicle size                      5.70
# vehicle type                     50.25
# dtype: float64

# %%
#making a copy to work on 
data2 = data.copy()
data2.shape
# Out:
# (10910, 25)

# %%
#As there are not so much missing NaN values. We will not drop them. Instead we will replace them with a suitable value.
data2['state'] = data2['state'].fillna('NA')
data2['vehicle class'] = data2['vehicle class'].fillna('NA')
data2['vehicle size'] = data2['vehicle size'].fillna('NA')

# %%
data2 = data2.dropna(subset=['months since last claim'])

# %%
data2 = data2.dropna(subset=['response'])

# %%
data2.isna().sum()
# Out:
# customer                            0
# state                               0
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim             0
# months since policy inception       0
# number of open complaints           0
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                       0
# vehicle size                        0
# vehicle type                     4865
# dtype: int64

# %%
data2.shape
# Out:
# (9688, 25)

# %%
data2.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 6  IW72280  California              5035.035257       No     Basic    Doctor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 6           2/14/11         Employed      F   37405  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# 1                       0.0                  1   Personal Auto   Personal L3
# 2                       0.0                  2   Personal Auto   Personal L3
# 3                       0.0                  2  Corporate Auto  Corporate L3
# 6                       3.0                  4  Corporate Auto  Corporate L2
#
#    renew offer type  sales channel  total claim amount  vehicle class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 6            Offer2         Branch          287.556107  Four-Door Car
#
#   vehicle size vehicle type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 6      Medsize          NaN
#
# [5 rows x 25 columns]

# %%
#dropping the whole column Vehicle type as more than half the values are NaN
data2 = data2.drop(['vehicle type'], axis=1)

# %%
data2.shape
# Out:
# (9688, 24)

# %%
#Datetime format - Extract the months from the dataset and store in a separate column. 
#Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9688 entries, 0 to 10908
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9688 non-null   object
#  1   state                          9688 non-null   object
#  2   customer lifetime value        9688 non-null   float64
#  3   response                       9688 non-null   object
#  4   coverage                       9688 non-null   object
#  5   education                      9688 non-null   object
#  6   effective to date              9688 non-null   object
#  7   employmentstatus               9688 non-null   object
#  8   gender                         9688 non-null   object
#  9   income                         9688 non-null   int64
#  10  location code                  9688 non-null   object
#  11  marital status                 9688 non-null   object
#  12  monthly premium auto           9688 non-null   int64
#  13  months since last claim        9688 non-null   float64
#  14  months since policy inception  9688 non-null   int64
#  15  number of open complaints      9688 non-null   float64
#  16  number of policies             9688 non-null   int64
#  17  policy type                    9688 non-null   object
#  18  policy                         9688 non-null   object
#  19  renew offer type               9688 non-null   object
#  20  sales channel                  9688 non-null   object
#  21  total claim amount             9688 non-null   float64
#  22  vehicle class                  9688 non-null   object
#  23  vehicle size                   9688 non-null   object
# dtypes: float64(4), int64(4), object(16)
# memory usage: 1.8+ MB

# %%
#created another column called date
data2['date'] = pd.to_datetime(data2['effective to date'])

# %%
#created months
data2['month'] = data2['date'].dt.month

# %%
data2.head()

# %%
#Displaying by month, where 1 is January and 2 is February
#filtered = data2[data2['month'].isin([1,2,3])]
filtered = data2[data2['month']<= 3]

# %%
filtered
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective to date employmentstatus gender  income  \
# 0                   College           2/18/11         Employed      M   48029
# 1                   College           1/18/11       Unemployed      F       0
# 2                  Bachelor           2/10/11         Employed      M   22139
# 3                   College           1/11/11         Employed      M   49078
# 6                    Doctor           2/14/11         Employed      F   37405
# ...                     ...               ...              ...    ...     ...
# 10903               College            1/7/11         Employed      M   59855
# 10904  High School or Below           2/24/11       Unemployed      M       0
# 10906               College            1/6/11         Employed      F   61146
# 10907              Bachelor            2/6/11         Employed      F   39837
# 10908               College           2/13/11         Employed      F   64195
#
#        ... number of policies     policy type        policy  renew offer type  \
# 0      ...                  9  Corporate Auto  Corporate L3            Offer3
# 1      ...                  1   Personal Auto   Personal L3            Offer4
# 2      ...                  2   Personal Auto   Personal L3            Offer3
# 3      ...                  2  Corporate Auto  Corporate L3            Offer2
# 6      ...                  4  Corporate Auto  Corporate L2            Offer2
# ...    ...                ...             ...           ...               ...
# 10903  ...                  1   Personal Auto   Personal L2            Offer2
# 10904  ...                  2   Personal Auto   Personal L2            Offer1
# 10906  ...                  6   Personal Auto   Personal L3            Offer2
# 10907  ...                  2  Corporate Auto  Corporate L3            Offer1
# 10908  ...                  6   Personal Auto   Personal L1            Offer1
#
#        sales channel  total claim amount  vehicle class vehicle size  \
# 0              Agent          292.800000  Four-Door Car      Medsize
# 1        Call Center          744.924331  Four-Door Car      Medsize
# 2        Call Center          480.000000            SUV      Medsize
# 3             Branch          484.013411  Four-Door Car      Medsize
# 6             Branch          287.556107  Four-Door Car      Medsize
# ...              ...                 ...            ...          ...
# 10903         Branch          355.200000   Two-Door Car      Medsize
# 10904         Branch          897.600000     Luxury SUV      Medsize
# 10906         Branch          273.018929  Four-Door Car      Medsize
# 10907            Web          381.306996     Luxury SUV      Medsize
# 10908         Branch          618.288849            SUV      Medsize
#
#             date month
# 0     2011-02-18     2
# 1     2011-01-18     1
# 2     2011-02-10     2
# 3     2011-01-11     1
# 6     2011-02-14     2
# ...          ...   ...
# 10903 2011-01-07     1
# 10904 2011-02-24     2
# 10906 2011-01-06     1
# 10907 2011-02-06     2
# 10908 2011-02-13     2
#
# [9688 rows x 26 columns]

# %%
data2['month'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
# BONUS: Put all the previously mentioned data transformations into a function.

def month(df):
    
    cols = []
    for column in df.columns:
        cols.append(column.lower())
    df.columns = cols
    
    df = df.rename(columns={'unnamed: 0':'index'})
    df = df.drop(['index'], axis=1)
    
    df['response'] = df['response'].fillna('NA')
    df['state'] = df['state'].fillna('NA')
    df['vehicle class'] = df['vehicle class'].fillna('NA')
    df['vehicle size'] = df['vehicle size'].fillna('NA')
    
    df = df.dropna(subset=['months since last claim'])
    df = df.drop(['vehicle type'], axis=1)
    
    df['date'] = pd.to_datetime(df['effective to date'])
    df['month'] = df['date'].dt.month
    filtered = df[df['month']<= 3]
    
    return filtered

# %%
#copying the original dataframe to a new variable to see if it works
data3 = pd.read_csv("marketing_customer_analysis.csv")

# %%
#It worked!
month(data3)
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 5      HO81102          NA              4745.181764       NA     Basic
# ...        ...         ...                      ...      ...       ...
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877          NA              6857.519928       NA     Basic
#
#                   education effective to date employmentstatus gender  income  \
# 0                   College           2/18/11         Employed      M   48029
# 1                   College           1/18/11       Unemployed      F       0
# 2                  Bachelor           2/10/11         Employed      M   22139
# 3                   College           1/11/11         Employed      M   49078
# 5      High School or Below           2/14/11         Employed      M   50549
# ...                     ...               ...              ...    ...     ...
# 10904  High School or Below           2/24/11       Unemployed      M       0
# 10906               College            1/6/11         Employed      F   61146
# 10907              Bachelor            2/6/11         Employed      F   39837
# 10908               College           2/13/11         Employed      F   64195
# 10909              Bachelor            1/8/11       Unemployed      M       0
#
#        ... number of policies     policy type        policy  renew offer type  \
# 0      ...                  9  Corporate Auto  Corporate L3            Offer3
# 1      ...                  1   Personal Auto   Personal L3            Offer4
# 2      ...                  2   Personal Auto   Personal L3            Offer3
# 3      ...                  2  Corporate Auto  Corporate L3            Offer2
# 5      ...                  7   Personal Auto   Personal L3            Offer1
# ...    ...                ...             ...           ...               ...
# 10904  ...                  2   Personal Auto   Personal L2            Offer1
# 10906  ...                  6   Personal Auto   Personal L3            Offer2
# 10907  ...                  2  Corporate Auto  Corporate L3            Offer1
# 10908  ...                  6   Personal Auto   Personal L1            Offer1
# 10909  ...                  3   Personal Auto   Personal L1            Offer4
#
#        sales channel  total claim amount  vehicle class vehicle size  \
# 0              Agent          292.800000  Four-Door Car      Medsize
# 1        Call Center          744.924331  Four-Door Car      Medsize
# 2        Call Center          480.000000            SUV      Medsize
# 3             Branch          484.013411  Four-Door Car      Medsize
# 5              Agent          292.800000  Four-Door Car      Medsize
# ...              ...                 ...            ...          ...
# 10904         Branch          897.600000     Luxury SUV      Medsize
# 10906         Branch          273.018929  Four-Door Car      Medsize
# 10907            Web          381.306996     Luxury SUV      Medsize
# 10908         Branch          618.288849            SUV      Medsize
# 10909            Web         1021.719397            SUV      Medsize
#
#             date month
# 0     2011-02-18     2
# 1     2011-01-18     1
# 2     2011-02-10     2
# 3     2011-01-11     1
# 5     2011-02-14     2
# ...          ...   ...
# 10904 2011-02-24     2
# 10906 2011-01-06     1
# 10907 2011-02-06     2
# 10908 2011-02-13     2
# 10909 2011-01-08     1
#
# [10277 rows x 26 columns]

# %% [markdown]
# # Lab | Customer Analysis Round 3

# %% [markdown]
# For this lab, we still keep using the marketing_customer_analysis.csv file. You can find the file in the files_for_lab folder.
#
# Get the data
# Use the same jupyter file from the last lab, Customer Analysis Round 3
# EDA (Exploratory Data Analysis) - Complete the following tasks to explore the data:
# - Show DataFrame info.
# - Describe DataFrame.
# - Show a plot of the total number of responses.
# - Show a plot of the response rate by the sales channel.
# - Show a plot of the response rate by the total claim amount.
# - Show a plot of the response rate by income.

# %% [markdown]
# **1. Show DataFrame info**
#
# **2. Describe DF**

# %%
#So using the variable data2 to as my dataframe

#Dataframe info
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9688 entries, 0 to 10908
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9688 non-null   object
#  1   state                          9688 non-null   object
#  2   customer lifetime value        9688 non-null   float64
#  3   response                       9688 non-null   object
#  4   coverage                       9688 non-null   object
#  5   education                      9688 non-null   object
#  6   effective to date              9688 non-null   object
#  7   employmentstatus               9688 non-null   object
#  8   gender                         9688 non-null   object
#  9   income                         9688 non-null   int64
#  10  location code                  9688 non-null   object
#  11  marital status                 9688 non-null   object
#  12  monthly premium auto           9688 non-null   int64
#  13  months since last claim        9688 non-null   float64
#  14  months since policy inception  9688 non-null   int64
#  15  number of open complaints      9688 non-null   float64
#  16  number of policies             9688 non-null   int64
#  17  policy type                    9688 non-null   object
#  18  policy                         9688 non-null   object
#  19  renew offer type               9688 non-null   object
#  20  sales channel                  9688 non-null   object
#  21  total claim amount             9688 non-null   float64
#  22  vehicle class                  9688 non-null   object
#  23  vehicle size                   9688 non-null   object
#  24  date                           9688 non-null   datetime64[ns]
#  25  month                          9688 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(5), object(16)
# memory usage: 2.0+ MB

# %%
data2.describe(include = 'all').T
# Out:
# C:\Users\ALP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#                                 count unique                  top  freq  \
# customer                         9688   9134              YT91759     3
# state                            9688      5           California  3346
# customer lifetime value        9688.0    NaN                  NaN   NaN
# response                         9688      2                   No  8300
# coverage                         9688      3                Basic  5911
# education                        9688      5             Bachelor  2917
# effective to date                9688     59              1/27/11   213
# employmentstatus                 9688      5             Employed  6042
# gender                           9688      2                    F  4940
# income                         9688.0    NaN                  NaN   NaN
# location code                    9688      3             Suburban  6134
# marital status                   9688      3              Married  5611
# monthly premium auto           9688.0    NaN                  NaN   NaN
# months since last claim        9688.0    NaN                  NaN   NaN
# months since policy inception  9688.0    NaN                  NaN   NaN
# number of open complaints      9688.0    NaN                  NaN   NaN
# number of policies             9688.0    NaN                  NaN   NaN
# policy type                      9688      3        Personal Auto  7217
# policy                           9688      9          Personal L3  3628
# renew offer type                 9688      4               Offer1  3989
# sales channel                    9688      4                Agent  3670
# total claim amount             9688.0    NaN                  NaN   NaN
# vehicle class                    9688      7        Four-Door Car  4621
# vehicle size                     9688      4              Medsize  6424
# date                             9688     59  2011-01-27 00:00:00   213
# month                          9688.0    NaN                  NaN   NaN
#
#                                    first       last          mean  \
# customer                             NaT        NaT           NaN
# state                                NaT        NaT           NaN
# customer lifetime value              NaT        NaT   8041.547925
# response                             NaT        NaT           NaN
# coverage                             NaT        NaT           NaN
# education                            NaT        NaT           NaN
# effective to date                    NaT        NaT           NaN
# employmentstatus                     NaT        NaT           NaN
# gender                               NaT        NaT           NaN
# income                               NaT        NaT  37671.451073
# location code                        NaT        NaT           NaN
# marital status                       NaT        NaT           NaN
# monthly premium auto                 NaT        NaT      93.21346
# months since last claim              NaT        NaT     15.129851
# months since policy inception        NaT        NaT     48.127581
# number of open complaints            NaT        NaT      0.383567
# number of policies                   NaT        NaT      2.961086
# policy type                          NaT        NaT           NaN
# policy                               NaT        NaT           NaN
# renew offer type                     NaT        NaT           NaN
# sales channel                        NaT        NaT           NaN
# total claim amount                   NaT        NaT    434.487753
# vehicle class                        NaT        NaT           NaN
# vehicle size                         NaT        NaT           NaN
# date                          2011-01-01 2011-02-28           NaN
# month                                NaT        NaT       1.46315
#
#                                         std          min          25%  \
# customer                                NaN          NaN          NaN
# state                                   NaN          NaN          NaN
# customer lifetime value          6961.74185  1898.007675  3990.182288
# response                                NaN          NaN          NaN
# coverage                                NaN          NaN          NaN
# education                               NaN          NaN          NaN
# effective to date                       NaN          NaN          NaN
# employmentstatus                        NaN          NaN          NaN
# gender                                  NaN          NaN          NaN
# income                         30377.598142          0.0          0.0
# location code                           NaN          NaN          NaN
# marital status                          NaN          NaN          NaN
# monthly premium auto              34.481609         61.0         68.0
# months since last claim           10.062316          0.0          6.0
# months since policy inception     27.912016          0.0         24.0
# number of open complaints          0.910502          0.0          0.0
# number of policies                 2.388212          1.0          1.0
# policy type                             NaN          NaN          NaN
# policy                                  NaN          NaN          NaN
# renew offer type                        NaN          NaN          NaN
# sales channel                           NaN          NaN          NaN
# total claim amount               291.629957     0.099007   272.715442
# vehicle class                           NaN          NaN          NaN
# vehicle size                            NaN          NaN          NaN
# date                                    NaN          NaN          NaN
# month                              0.498666          1.0          1.0
#
#                                        50%          75%          max
# customer                               NaN          NaN          NaN
# state                                  NaN          NaN          NaN
# customer lifetime value        5772.565542  8983.147788  83325.38119
# response                               NaN          NaN          NaN
# coverage                               NaN          NaN          NaN
# education                              NaN          NaN          NaN
# effective to date                      NaN          NaN          NaN
# employmentstatus                       NaN          NaN          NaN
# gender                                 NaN          NaN          NaN
# income                             34083.5      62272.5      99981.0
# location code                          NaN          NaN          NaN
# marital status                         NaN          NaN          NaN
# monthly premium auto                  83.0        109.0        298.0
# months since last claim               14.0         23.0         35.0
# months since policy inception         48.0         71.0         99.0
# number of open complaints              0.0          0.0          5.0
# number of policies                     2.0          4.0          9.0
# policy type                            NaN          NaN          NaN
# policy                                 NaN          NaN          NaN
# renew offer type                       NaN          NaN          NaN
# sales channel                          NaN          NaN          NaN
# total claim amount              383.076998        547.2  2893.239678
# vehicle class                          NaN          NaN          NaN
# vehicle size                           NaN          NaN          NaN
# date                                   NaN          NaN          NaN
# month                                  1.0          2.0          2.0

# %% [markdown]
# **3. Show a plot of the total number of responses.**

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
# Out:
# C:\Users\ALP\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# %matplotlib inline

# %%
ax = sns.countplot(x="response", data=data2)

# %%
data2['response'].value_counts().plot(kind='bar')

# %% [markdown]
# **4. Show a plot of the response rate by the sales channel.**

# %%
#We see that the Agents have been putting in a lot of work to get responses.
ax = sns.countplot(x="sales channel",  hue="response", data=data2, palette = "Set1")

# %% [markdown]
# **5.#Show a plot of the response rate by the total claim amount.**

# %%
sns.catplot(x="response", y="total claim amount", order=["No", "Yes"], data=data2)

# %%
ax = sns.stripplot(x="response", y="total claim amount", data=data2)

# %%
ax = sns.violinplot(x="response", y="total claim amount", data=data2)

# %% [markdown]
# **6.Show a plot of the response rate by income.**

# %%
#box plots
ax = sns.boxplot(x="response", y="income", data=data2)

# %%
#I see lots of values that are zero, that is why they seperate from rest of the values at the bottom of the plot
#perhaps its better to remove them
ax = sns.stripplot(x="response", y="income", data=data2)

# %%
ax = sns.violinplot(x="response", y="income", data=data2)
